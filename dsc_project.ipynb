# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"/content/student_ml_dataset.csv")

# %%
df
# Out:
#                   Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 0          Derek Smith   26  Female       6.596347   98             68
# 1    Christopher Boyle   37    Male       5.672202  133             44
# 2        Bradley Jones   19    Male       6.282581   89             90
# 3        Eric Martinez   21    Male       8.004422  106             81
# 4     Jennifer Ferrell   29  Female       4.322501   88             41
# ..                 ...  ...     ...            ...  ...            ...
# 995      Jonathan Long   29  Female       4.525427  100             64
# 996     Michael Morgan   34  Female       9.049785  129             70
# 997   Jacob Cunningham   29    Male       5.942553  108             68
# 998  Brittany Matthews   39  Female       5.268965  120             73
# 999      Daniel Kramer   28  Female       9.840650  106             74
#
#      Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# 0           100               43               True
# ...

# %%
df.dtypes
# Out:
# Name                  object
# Age                    int64
# Gender                object
# Hours_Studied        float64
# IQ                     int64
# Physics_Marks          int64
# Math_Marks             int64
# Chemistry_Marks        int64
# Has_Part_Time_Job       bool
# dtype: object

# %% [markdown]
# df.describe(include=all)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                   Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 0          Derek Smith   26  Female       6.596347   98             68
# 1    Christopher Boyle   37    Male       5.672202  133             44
# 2        Bradley Jones   19    Male       6.282581   89             90
# 3        Eric Martinez   21    Male       8.004422  106             81
# 4     Jennifer Ferrell   29  Female       4.322501   88             41
# ..                 ...  ...     ...            ...  ...            ...
# 995      Jonathan Long   29  Female       4.525427  100             64
# 996     Michael Morgan   34  Female       9.049785  129             70
# 997   Jacob Cunningham   29    Male       5.942553  108             68
# 998  Brittany Matthews   39  Female       5.268965  120             73
# 999      Daniel Kramer   28  Female       9.840650  106             74
#
#      Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# ...

# %%
plt.hist(df['Age'], bins=10)
plt.xlabel('Age')
plt.title('Age Distribution')
plt.show()

# Example of a count plot for a categorical variable
sns.countplot(df['Hours_Studied'])
plt.ylabel('Count')
plt.title('Hours Studied')
plt.show()

# %%
plt.scatter(df['Age'], df['Physics_Marks'])
plt.xlabel('Age')
plt.ylabel('Physics Marks')
plt.title('Age vs. Physics Score')
plt.show()

plt.scatter(df['Age'], df['Math_Marks'])
plt.xlabel('Age')
plt.ylabel('Maths Marks')
plt.title('Age vs. Maths Score')
plt.show()

plt.scatter(df['Age'], df['Chemistry_Marks'])
plt.xlabel('Age')
plt.ylabel('Chemistry Marks')
plt.title('Age vs. Chemistry Score')
plt.show()

# Example of a correlation matrix to explore correlations between numerical variables
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-16-bb04087887c4>:20: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
sns.pairplot(df[['Age', 'Hours_Studied', 'IQ']])
plt.title('Pair Plot of Age, IQ, and Study Hours')
plt.show()
